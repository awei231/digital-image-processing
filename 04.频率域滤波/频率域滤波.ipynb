# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

# %%
image_base_path = "../image_data/DIP3E_Original_Images_CH04/"

# %% [markdown]
# ## 图像重取样

# %%
image = Image.open(os.path.join(image_base_path,"Fig0417(a)(barbara).tif"))
image = np.asarray(image)
image = image.astype("uint8")
plt.imshow(image,cmap="gray")

# %% [markdown]
# ### 混淆

# %%
tmp_image = list()

def resize_half(image):
    """图像缩放为以前的二分之一
    """
    tmp_image = list()
    
    for i_row in range(image.shape[0]):
        tmp_row = list()
        if i_row % 2 == 0:
            continue
        for j_col in range(image.shape[1]):
            if j_col % 2 == 0:
                continue
            tmp_row.append(image[i_row][j_col])
        tmp_image.append(tmp_row)
        
    tmp_image = np.asarray(tmp_image)
    return tmp_image

# %%
print("原图像Shape:{}".format(image.shape))
image2 = resize_half(image)
print("压缩后的Shape：{}".format(image2.shape))
# Out:
# 原图像Shape:(566, 402)
# 压缩后的Shape：(283, 201)

# %%
image3 = cv2.boxFilter(image,-1,(3,3),normalize = True)
image3 = resize_half(image3)

_,(ax1,ax2,ax3) = plt.subplots(1,3,figsize = (20,10))
ax1.imshow(image,cmap = "gray")
ax1.set_title("Source Image")
ax2.imshow(image2,cmap = "gray")
ax2.set_title("Resize Half Image")
ax3.imshow(image3,cmap = "gray")
ax3.set_title("Smooth Resize Image")

plt.show()
# plt.imshow(tmp_image,cmap = "gray")

# %% [markdown]
# ### 锯齿

# %%
image = Image.open(os.path.join(image_base_path,"Fig0418(a)(ray_traced_bottle_original).tif"))
image = np.asarray(image)
image = image.astype(np.uint8)
kernel = np.array([[0, 1, 0],
                   [1, -4, 1],
                   [0, 1, 0]])
image1 = cv2.filter2D(image, -1, kernel)
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
ax1.imshow(image, cmap="gray")
ax1.set_title("Source Image")
ax2.imshow(image1, cmap="gray")
ax2.set_title("Edge Detection")
# Out:
# Text(0.5, 1.0, 'Edge Detection')

# %% [markdown]
# # 傅里叶谱的性质

# %%
sns.set_style("white")
image = Image.open(os.path.join(image_base_path,"Fig0424(a)(rectangle).tif"))
image = np.asarray(image)
plt.imshow(image)

# %% [markdown]
# ## 原图像谱

# %%
sns.set_style("white")
_,axe = plt.subplots(1,4,figsize = (15,8))

"""原图像"""
axe[0].imshow(image,cmap = "gray")

"""傅里叶谱"""
fft_image = np.fft.fft2(image)
axe[1].imshow(1 + np.log(np.abs(1 + fft_image)))

"""中心化后的傅里叶谱"""
tmp_image = np.zeros_like(image)
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        tmp_image[i][j] = image[i][j] * np.power(-1,i + j)
        
tmp_fft_image = np.fft.fft2(tmp_image)
axe[2].imshow(np.abs(tmp_fft_image))

"""添加log"""
axe[3].imshow((1 + np.log(np.abs(tmp_fft_image)+ 1e-10)))

# %% [markdown]
# ## 平移和旋转后的谱（TODO）

# %%
translation_image = Image.open(os.path.join(image_base_path,"Fig0425(a)(translated_rectangle).tif"))

image_shape = image.shape
image_shape = tuple(image_shape)

rotate_matrix = cv2.getRotationMatrix2D(image_shape,-45,1)
rotate_image = cv2.warpAffine(image,rotate_matrix,image_shape)
plt.imshow(rotate_image)

# %% [markdown]
# # 频率域滤波

# %%
image = Image.open(os.path.join(image_base_path,"Fig0429(a)(blown_ic).tif"))
image = np.asarray(image)
plt.imshow(image,cmap = "gray")

# %% [markdown]
# ## 直流分量置0

# %%
sns.set_style("white")
_,axe = plt.subplots(1,4,figsize = (20,15))

axe[0].imshow(image,cmap = "gray")
axe[0].set_title("source Image")

"""频谱图"""
w,h = image.shape

fft_image = np.fft.fft2(image)
fft_image = np.fft.fftshift(fft_image)

axe[1].imshow(np.log(1 + np.abs(fft_image)))
axe[1].set_title("Freq Image")
# axe[1].colorbar()

"""去除直流分量"""
mask = np.ones_like(fft_image,dtype=int)

scope = 10
mask[(w//2 - scope):(w//2 + scope),(h//2 -scope):(h//2 + scope)] = 0
fft_image = fft_image * mask 
axe[2].imshow(np.log(1 + np.abs(fft_image)),)
axe[2].set_title("Freq Image of Remove Center")
# axe[2].colorbar()

"""还原结果图"""
r_image = np.fft.ifft2(np.fft.ifftshift(fft_image))
axe[3].imshow(r_image.real,cmap="gray")
axe[3].set_title("Result Image")
# axe[3].colorbar()
# Out:
# Text(0.5, 1.0, 'Result Image')

# %% [markdown]
# ## 高斯滤波器

# %%
def get_two_dim_gaussian_kernel(shape:(int,int),sigma:float) -> np.ndarray:
    """返回二维的高斯核
    """
    x = cv2.getGaussianKernel(shape[0],sigma)
    y = cv2.getGaussianKernel(shape[1],sigma)
    return np.multiply(x,np.transpose(y))

# %%
from mpl_toolkits import mplot3d

ax = plt.axes(projection='3d')
gaussian_kernel = get_two_dim_gaussian_kernel(image.shape,100)
x, y = np.meshgrid(np.arange(gaussian_kernel.shape[1]), np.arange(gaussian_kernel.shape[0]))
ax.plot_surface(x, y, gaussian_kernel, cmap='viridis', edgecolor='k', linewidth=0.5)

# %%
w,h = image.shape
fft_image = np.fft.fft2(image)
fft_image = np.fft.fftshift(fft_image)

kernel1 = get_two_dim_gaussian_kernel(fft_image.shape, 10)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x, y = np.meshgrid(np.arange(kernel1.shape[1]), np.arange(kernel1.shape[0]))
ax.plot_surface(x, y, kernel1, cmap='viridis', edgecolor='k', linewidth=0.5)
plt.show()

fft_image1 = fft_image *  ( kernel1)
fft_image1 = np.fft.ifftshift(fft_image1)
r_image1 = np.fft.ifft2(fft_image1)
plt.imshow(r_image1.real)

# %%
image = Image.open(os.path.join(image_base_path,"Fig0441(a)(characters_test_pattern).tif"))
image = np.asarray(image)
img2 = cv2.GaussianBlur(image, (3, 3), 0)
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
ax1.imshow(img2)
ax2.imshow(image)

# %%
傅里叶变换

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 读取图像
image = cv2.imread("../image_data/DIP3E_Original_Images_CH04/Fig0417(a)(barbara).tif", cv2.IMREAD_GRAYSCALE)

# 进行二维傅里叶变换
fft_result = np.fft.fft2(image)
fft_shifted = np.fft.fftshift(fft_result)

# 计算频谱图的幅度谱
magnitude_spectrum = np.abs(fft_shifted)

# 绘制原始图像和频谱图
plt.figure(figsize=(12, 6))

plt.subplot(121)
plt.imshow(image, cmap='gray')
plt.title('Original Image')

plt.subplot(122)
plt.imshow(np.log(1 + magnitude_spectrum), cmap='gray')  # 使用对数尺度以便更清晰地观察
plt.title('Magnitude Spectrum')

plt.show()

# %%
# 读取图像
image = cv2.imread("../image_data/DIP3E_Original_Images_CH04/Fig0417(a)(barbara).tif", cv2.IMREAD_GRAYSCALE)

# 进行傅里叶变换
fft_result = np.fft.fft2(image)
fft_shifted = np.fft.fftshift(fft_result)

# 计算频谱图的幅度谱
magnitude_spectrum = np.log(np.abs(fft_shifted) + 1)

# 将结果进行逆变换
ifft_result = np.fft.ifft2(fft_result)

# 获取逆变换的实部
ifft_result_real = np.real(ifft_result)

# 将实部的数值范围缩放到合适的范围
ifft_result_scaled = np.abs(ifft_result_real)
ifft_result_scaled = np.uint8(255 * ifft_result_scaled / np.max(ifft_result_scaled))

# 设置图像大小
plt.figure(figsize=(15, 5))

# 显示原始图像、傅里叶变换结果和逆变换结果
plt.subplot(131), plt.imshow(image, cmap='gray'), plt.title('Original Image')
plt.subplot(132), plt.imshow(magnitude_spectrum, cmap='gray'), plt.title('Magnitude Spectrum')
plt.subplot(133), plt.imshow(ifft_result_scaled, cmap='gray'), plt.title('Inverse FFT Result')
plt.show()

# %%
# 读取图像
image = cv2.imread("../image_data/DIP3E_Original_Images_CH04/Fig0417(a)(barbara).tif", cv2.IMREAD_GRAYSCALE)

# 进行傅里叶变换
fft_result = np.fft.fft2(image)
fft_shifted = np.fft.fftshift(fft_result)

# 定义平滑滤波器（这里使用简单的均值滤波器）
smooth_filter = np.ones_like(fft_shifted) / fft_shifted.size

# 应用平滑滤波
smoothed_fft = fft_shifted * smooth_filter

# 定义锐化滤波器（这里使用拉普拉斯滤波器）
sharpening_filter = np.array([[0, -1, 0],
                              [-1, 5, -1],
                              [0, -1, 0]])

# 将傅里叶变换结果的实部转换为合适的数据类型
fft_shifted_real = np.real(fft_shifted)
fft_shifted_real = fft_shifted_real.astype(np.float32)

# 使用cv2.filter2D应用锐化滤波
sharpened_fft = cv2.filter2D(fft_shifted_real, -1, sharpening_filter)

# 计算频谱图的幅度谱
magnitude_spectrum = np.log(np.abs(fft_shifted) + 1)

# 将结果进行逆变换
smoothed_ifft = np.fft.ifft2(np.fft.ifftshift(smoothed_fft))
sharpened_ifft = np.fft.ifft2(np.fft.ifftshift(sharpened_fft))

# 获取逆变换的实部
smoothed_ifft_real = np.real(smoothed_ifft)
sharpened_ifft_real = np.real(sharpened_ifft)

# 将实部的数值范围缩放到合适的范围
smoothed_ifft_scaled = np.abs(smoothed_ifft_real)
smoothed_ifft_scaled = np.uint8(255 * smoothed_ifft_scaled / np.max(smoothed_ifft_scaled))

sharpened_ifft_scaled = np.abs(sharpened_ifft_real)
sharpened_ifft_scaled = np.uint8(255 * sharpened_ifft_scaled / np.max(sharpened_ifft_scaled))

# 设置图像大小
plt.figure(figsize=(20, 10))

# 显示原始图像、傅里叶变换结果和处理后的结果
plt.subplot(231), plt.imshow(image, cmap='gray'), plt.title('Original Image')
plt.subplot(232), plt.imshow(magnitude_spectrum, cmap='gray'), plt.title('Magnitude Spectrum')
plt.subplot(233), plt.imshow(smoothed_ifft_scaled, cmap='gray'), plt.title('Smoothed Image')
plt.subplot(234), plt.imshow(image, cmap='gray'), plt.title('Original Image')
plt.subplot(235), plt.imshow(magnitude_spectrum, cmap='gray'), plt.title('Magnitude Spectrum')
plt.subplot(236), plt.imshow(sharpened_ifft_scaled, cmap='gray'), plt.title('Sharpened Image')

plt.show()

# %%
# 读取图像
image = cv2.imread("../image_data/DIP3E_Original_Images_CH04/Fig0417(a)(barbara).tif", cv2.IMREAD_GRAYSCALE)

# 进行二维傅里叶变换
fft_result = np.fft.fft2(image)
fft_shifted = np.fft.fftshift(fft_result)

# 计算频谱图的幅度谱
magnitude_spectrum = np.log(np.abs(fft_shifted) + 1)

# 定义平滑滤波核
smoothing_filter = np.ones_like(fft_shifted) / np.prod(fft_shifted.shape)

# 应用平滑滤波
smoothed_fft = fft_shifted * smoothing_filter

# 定义锐化滤波核
sharpening_filter = np.array([[0, -1, 0],
                               [-1, 5, -1],
                               [0, -1, 0]])

# 使用cv2.filter2D应用锐化滤波
sharpened_fft = cv2.filter2D(fft_shifted, -1, sharpening_filter)

# 可视化频谱图
plt.figure(figsize=(12, 6))

# 原始频谱图
plt.subplot(131)
plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('Original Spectrum')
plt.colorbar()

# 平滑滤波后的频谱图
smoothed_spectrum = np.log(np.abs(smoothed_fft) + 1)
plt.subplot(132)
plt.imshow(smoothed_spectrum, cmap='gray')
plt.title('Smoothed Spectrum')
plt.colorbar()

# 锐化滤波后的频谱图
sharpened_spectrum = np.log(np.abs(sharpened_fft) + 1)
plt.subplot(133)
plt.imshow(sharpened_spectrum, cmap='gray')
plt.title('Sharpened Spectrum')
plt.colorbar()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [15], in <cell line: 23>()
#      18 sharpening_filter = np.array([[0, -1, 0],
#      19                                [-1, 5, -1],
#      20                                [0, -1, 0]])
#      22 # 使用cv2.filter2D应用锐化滤波
# ---> 23 sharpened_fft = cv2.filter2D(fft_shifted, -1, sharpening_filter)
#      25 # 可视化频谱图
#      26 plt.figure(figsize=(12, 6))
#
# error: OpenCV(4.5.5) :-1: error: (-5:Bad argument) in function 'filter2D'
# > Overload resolution failed:
# >  - src data type = 15 is not supported
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
# 读取图像
image = cv2.imread("../image_data/DIP3E_Original_Images_CH04/Fig0417(a)(barbara).tif", cv2.IMREAD_GRAYSCALE)

# 进行二维傅里叶变换
fft_result = np.fft.fft2(image)
fft_shifted = np.fft.fftshift(fft_result)

# 计算频谱图的幅度谱
magnitude_spectrum = np.log(np.abs(fft_shifted) + 1)

# 定义平滑滤波核
smoothing_filter = np.ones_like(fft_shifted) / np.prod(fft_shifted.shape)

# 应用平滑滤波
smoothed_fft = fft_shifted * smoothing_filter

# 将傅里叶变换的结果取实部，丢弃虚部
fft_shifted_real = np.real(fft_shifted)

# 定义锐化滤波核
sharpening_filter = np.array([[0, -1, 0],
                               [-1, 5, -1],
                               [0, -1, 0]])

# 使用cv2.filter2D应用锐化滤波
sharpened_fft_real = cv2.filter2D(fft_shifted_real, -1, sharpening_filter)

# 可视化频谱图
plt.figure(figsize=(12, 6))

# 原始频谱图
plt.subplot(131)
plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('Original Spectrum')
plt.colorbar()

# 平滑滤波后的频谱图
smoothed_spectrum = np.log(np.abs(smoothed_fft) + 1)
plt.subplot(132)
plt.imshow(smoothed_spectrum, cmap='gray')
plt.title('Smoothed Spectrum')
plt.colorbar()

# 锐化滤波后的频谱图
sharpened_spectrum = np.log(np.abs(sharpened_fft_real) + 1)
plt.subplot(133)
plt.imshow(sharpened_spectrum, cmap='gray')
plt.title('Sharpened Spectrum')
plt.colorbar()

plt.tight_layout()
plt.show()
